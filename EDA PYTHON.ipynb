# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8792160d-ab04-49bf-ac8e-8b7faa174266" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8792160d-ab04-49bf-ac8e-8b7faa174266">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb2497b7-00d2-40fb-9f78-6ca94870a74c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb2497b7-00d2-40fb-9f78-6ca94870a74c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-892eba37-bc2e-440a-bf47-8131c4d19871" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-892eba37-bc2e-440a-bf47-8131c4d19871">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-900d2a56-6457-4192-984e-6d102d88d9b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-900d2a56-6457-4192-984e-6d102d88d9b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d1a6e608-3732-40aa-9674-a99f572f572f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1a6e608-3732-40aa-9674-a99f572f572f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# رفع الملفات
accidents = pd.read_excel("accidents.xlsx")
vehicles = pd.read_excel("vehicles.xlsx")
weather = pd.read_excel("weather_messy.csv T.csv.xlsx")
locations = pd.read_excel("locations_Clean.csv.xlsx")
casualties = pd.read_excel("casualties_messy.csv T.csv.xlsx")

# عرض أول 5 صفوف من كل جدول
print("Accidents Dataset:")
print(accidents.head(), "\n")

print("Vehicles Dataset:")
print(vehicles.head(), "\n")

print("Weather Dataset:")
print(weather.head(), "\n")

print("Locations Dataset:")
print(locations.head(), "\n")

print("Casualties Dataset:")
print(casualties.head())
# Out:
# Accidents Dataset:
#   Accident_ID  Country  Year      Month Day of Week time of day urban/rural  \
# 0    A0115402   Brazil  2023     August      Sunday     Morning       Rural
# 1    A0122863    Japan  2005    October      Monday   Afternoon       Urban
# 2    A0006286  Germany  2012  September      Friday     Morning       Rural
# 3    A0042703   Brazil  2019  September      Monday     Evening       Rural
# 4    A0032566    Japan  2003    October   Wednesday     Evening       Urban
#
#    Road Type Accident Severity      Accident Cause  \
# 0     Street             Minor  Mechanical Failure
# 1  Main Road            Severe  Mechanical Failure
# 2     Street          Moderate  Distracted Driving
# 3    Highway          Moderate       Drunk Driving
# 4  Main Road            Severe             Weather
#
#    Number of Vehicles Involved  Number of Injuries  Number of Fatalities  \
# 0                            3                  17                     1
# ...

# %%
import pandas as pd

# لو لسه محملتش، نرفع الملف
accidents = pd.read_excel("accidents.xlsx")

# نظرة سريعة
print(accidents.head())

# عدد الحوادث
total_accidents = accidents.shape[0]

# عدد الحوادث حسب الدولة
accidents_per_country = accidents['Country'].value_counts()

# أكثر شهر فيه حوادث
accidents_per_month = accidents['Month'].value_counts()

# أكثر يوم في الأسبوع فيه حوادث
accidents_per_day = accidents['Day of Week'].value_counts()

# أكثر وقت في اليوم فيه حوادث
accidents_per_time = accidents['time of day'].value_counts()

# أكثر سبب للحوادث
accidents_per_cause = accidents['Accident Cause'].value_counts()

# عرض النتائج
print(f"Total Accidents: {total_accidents}\n")
print("Accidents per Country:\n", accidents_per_country.head(), "\n")
print("Accidents per Month:\n", accidents_per_month.head(), "\n")
print("Accidents per Day of Week:\n", accidents_per_day.head(), "\n")
print("Accidents per Time of Day:\n", accidents_per_time.head(), "\n")
print("Top Accident Causes:\n", accidents_per_cause.head())
# Out:
#   Accident_ID  Country  Year      Month Day of Week time of day urban/rural  \
# 0    A0115402   Brazil  2023     August      Sunday     Morning       Rural
# 1    A0122863    Japan  2005    October      Monday   Afternoon       Urban
# 2    A0006286  Germany  2012  September      Friday     Morning       Rural
# 3    A0042703   Brazil  2019  September      Monday     Evening       Rural
# 4    A0032566    Japan  2003    October   Wednesday     Evening       Urban
#
#    Road Type Accident Severity      Accident Cause  \
# 0     Street             Minor  Mechanical Failure
# 1  Main Road            Severe  Mechanical Failure
# 2     Street          Moderate  Distracted Driving
# 3    Highway          Moderate       Drunk Driving
# 4  Main Road            Severe             Weather
#
#    Number of Vehicles Involved  Number of Injuries  Number of Fatalities  \
# 0                            3                  17                     1
# ...

# %%
weather.head()
# Out:
#   Accident_ID Weather Conditions   Visibility Level  Road Condition Weather_ID
# 0    A0120214              Snowy             142.777            Dry   W0120214
# 1    A0122525              Windy             185.999            Wet   W0122525
# 2    A0036050              Windy             428.164   Snow-Covered   W0036050
# 3    A0067488              Rainy             424.079   Snow-Covered   W0067488
# 4    A0130484              Rainy             130.499   Snow-Covered   W0130484

# %%
accidents_per_weather = weather['Weather Conditions'].value_counts()
print(accidents_per_weather)
# Out:
# Weather Conditions
# Windy    35139
# Rainy    24426
# Clear    24272
# Snowy    24153
# Foggy    24010
# Name: count, dtype: int64

# %%
accidents_per_road_condition = weather['Road Condition'].value_counts()
print(accidents_per_road_condition)
# Out:
# Road Condition
# Icy             40809
# Wet             30660
# Snow-Covered    30358
# Dry             30173
# Name: count, dtype: int64

# %%
locations.head()
# Out:
#   Accident_ID Country         Region Urban/Rural  Road Type Road Condition  \
# 0    A0000001     USA         Europe       Rural     Street            Wet
# 1    A0000002      UK  North America       Urban     Street   Snow-Covered
# 2    A0000003     USA  South America       Urban    Highway            Wet
# 3    A0000004      UK      Australia       Urban  Main Road            Icy
# 4    A0000005  Canada  South America       Rural    Highway            Icy
#
#    Population Density     Location_ID
# 0         3866.273014  L_1b18e3a7ee20
# 1         2333.916224  L_773b7ad3fcce
# 2         4408.889129  L_e9dc72247563
# 3         2810.822423  L_32c0ef205f12
# 4         3883.645634  L_228ad5cbfa1b

# %%
accidents_per_region = locations['Region'].value_counts()
print(accidents_per_region)
# Out:
# Region
# Europe           30
# North America    30
# South America    30
# Australia        30
# Asia             30
# Name: count, dtype: int64

# %%
accidents_urban_rural = locations['Urban/Rural'].value_counts()
print(accidents_urban_rural)
# Out:
# Urban/Rural
# Rural    75
# Urban    75
# Name: count, dtype: int64

# %%
accidents_per_road_type = locations['Road Type'].value_counts()
print(accidents_per_road_type)
# Out:
# Road Type
# Street       50
# Highway      50
# Main Road    50
# Name: count, dtype: int64

# %%
locations['Population Density'].describe()
# Out:
# count     150.000000
# mean     2475.778460
# std      1393.943860
# min        44.528112
# 25%      1489.341687
# 50%      2568.659845
# 75%      3612.605875
# max      4996.125166
# Name: Population Density, dtype: float64

# %%
vehicles.head()
# Out:
#   Accident_ID   Vehicle_ID  Vehicle_Position Vehicle Condition
# 0    A0072701  A0072701_V4                 4              Good
# 1    A0056369  A0056369_V1                 1              Good
# 2    A0100315  A0100315_V3                 3          Moderate
# 3    A0113982  A0113982_V2                 2          Moderate
# 4    A0026284  A0026284_V1                 1          Moderate

# %%
vehicles['Vehicle Condition'].value_counts()
# Out:
# Vehicle Condition
# Good        127806
# Moderate    101221
# Poor        101135
# Name: count, dtype: int64

# %%
# Total Accidents
total_accidents = accidents['Accident_ID'].nunique()

# Total Injuries, Fatalities, Casualties
total_injuries = accidents['Number of Injuries'].sum()
total_fatalities = accidents['Number of Fatalities'].sum()
total_casualties = total_injuries + total_fatalities

# Average Rates
avg_fatality_rate = total_fatalities / total_casualties
avg_injury_rate = total_injuries / total_casualties

# Top 5 Accident Causes
top_causes = accidents['Accident Cause'].value_counts().head(5)

# Accidents per Country
accidents_per_country = accidents['Country'].value_counts()

# Accidents per Month
accidents_per_month = accidents['Month'].value_counts()

# Accidents per Day of Week
accidents_per_day = accidents['Day of Week'].value_counts()

# Accidents per Time of Day
accidents_per_time = accidents['time of day'].value_counts()

# Weather Conditions
accidents_per_weather = weather['Weather Conditions'].value_counts()

# Road Conditions
accidents_per_road = weather['Road Condition'].value_counts()

# Display results
print(f"Total Accidents: {total_accidents}\n")
print(f"Total Casualties: {total_casualties}")
print(f"Total Injuries: {total_injuries}")
print(f"Total Fatalities: {total_fatalities}")
print(f"Average Fatality Rate: {avg_fatality_rate:.6f}")
print(f"Average Injury Rate: {avg_injury_rate:.6f}\n")

print("Top 5 Accident Causes:")
print(top_causes, "\n")

print("Accidents per Country:")
print(accidents_per_country, "\n")

print("Accidents per Month:")
print(accidents_per_month, "\n")

print("Accidents per Day of Week:")
print(accidents_per_day, "\n")

print("Accidents per Time of Day:")
print(accidents_per_time, "\n")

print("Accidents per Weather Condition:")
print(accidents_per_weather, "\n")

print("Accidents per Road Condition:")
print(accidents_per_road)
# Out:
# Total Accidents: 132000
#
# Total Casualties: 1518481
# Total Injuries: 1255083
# Total Fatalities: 263398
# Average Fatality Rate: 0.173462
# Average Injury Rate: 0.826538
#
# Top 5 Accident Causes:
# Accident Cause
# Drunk Driving         26506
# Distracted Driving    26460
# Speeding              26446
# Mechanical Failure    26343
# Weather               26245
# Name: count, dtype: int64
#
# Accidents per Country:
# Country
# Canada       22838
# Brazil       12268
# Germany      12260
# Australia    12197
# Uk           12196
# India        12188
# Usa          12105
# China        12089
# Japan        11992
# Russia       11867
# Name: count, dtype: int64
#
# Accidents per Month:
# Month
# May          20794
# June         10272
# March        10227
# April        10214
# February     10166
# September    10144
# July         10133
# October      10090
# January      10082
# December     10041
# August        9923
# November      9914
# Name: count, dtype: int64
#
# ...

# %%
from google.colab import files

# لو عايز تصدر كل جدول كـ CSV
accidents.to_csv("accidents_clean.csv", index=False)
vehicles.to_csv("vehicles_clean.csv", index=False)
weather.to_csv("weather_clean.csv", index=False)
locations.to_csv("locations_clean.csv", index=False)
casualties.to_csv("casualties_clean.csv", index=False)

# تحميل الملفات على جهازك
files.download("accidents_clean.csv")
files.download("vehicles_clean.csv")
files.download("weather_clean.csv")
files.download("locations_clean.csv")
files.download("casualties_clean.csv")
